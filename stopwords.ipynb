# %%
corpus= """Learning is one of the most important parts of human life because it allows us to grow, adapt, and understand the world around us. It is not limited to classrooms or textbooks; people learn through experiences, mistakes, conversations, and challenges. In today’s rapidly changing world, continuous learning has become even more important because technology and society are constantly evolving. A person who is willing to learn from failure can turn mistakes into valuable lessons and become stronger over time. Just like a character in an anime who starts weak but becomes powerful through training, real-life growth also comes from patience, consistency, and effort. Ultimately, learning is not about knowing everything, but about remaining curious enough to keep improving.
 """

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

cv.fit([corpus])
cv.vocabulary_
# Out:
# {'learning': 46,
#  'is': 40,
#  'one': 56,
#  'of': 55,
#  'the': 72,
#  'most': 53,
#  'important': 36,
#  'parts': 59,
#  'human': 35,
#  'life': 48,
#  'because': 9,
#  'it': 41,
#  'allows': 2,
#  'us': 81,
#  'to': 75,
#  'grow': 32,
#  'adapt': 1,
#  'and': 5,
#  'understand': 80,
#  'world': 86,
#  'around': 8,
#  'not': 54,
#  'limited': 50,
#  'classrooms': 17,
#  'or': 57,
#  'textbooks': 71,
#  'people': 61,
#  'learn': 45,
#  'through': 73,
#  'experiences': 29,
#  'mistakes': 51,
#  'conversations': 22,
#  'challenges': 14,
#  'in': 38,
#  'today': 76,
#  'rapidly': 64,
#  'changing': 15,
#  'continuous': 21,
#  'has': 34,
#  'become': 10,
#  'even': 26,
#  'more': 52,
#  'technology': 70,
#  'society': 67,
#  'are': 7,
#  'constantly': 20,
#  'evolving': 28,
#  'person': 62,
#  'who': 84,
#  'willing': 85,
#  'from': 31,
#  'failure': 30,
#  'can': 13,
#  'turn': 78,
#  'into': 39,
#  'valuable': 82,
#  'lessons': 47,
#  'stronger': 69,
#  'over': 58,
#  'time': 74,
# ...

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Sahil\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
stemmer = PorterStemmer()
sentences = nltk.sent_tokenize(corpus)

# %%
for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])  
    words=[stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = ' '.join(words) #converting all the words in sentences

# %%
sentences
# Out:
# ['learn one import part human life allow us grow , adapt , understand world around us .',
#  'it limit classroom textbook ; peopl learn experi , mistak , convers , challeng .',
#  'in today ’ rapidli chang world , continu learn becom even import technolog societi constantli evolv .',
#  'a person will learn failur turn mistak valuabl lesson becom stronger time .',
#  'just like charact anim start weak becom power train , real-lif growth also come patienc , consist , effort .',
#  'ultim , learn know everyth , remain curiou enough keep improv .']

# %%
sentence = "Learning is one of the most important parts of human life because it allows us to grow"

# %%
shabad = nltk.word_tokenize(sentence)

# %%
import nltk

nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Sahil\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
tag_elements=nltk.pos_tag(shabad)

# %%
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Sahil\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Sahil\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True
